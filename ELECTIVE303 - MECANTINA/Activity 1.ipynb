# %% [markdown]
# <h1>Activity 1 - PALMER PENGUIN DATA ANALYTICS PROJECT</h1>
# <hr>
# <h3>Analyst : Nerjie Angelo Mecantina</h3>

# %%
#import Libraries

import pandas as pd
import numpy as np

# %% [markdown]
# <h2>Converting Dataset(s) into Dataframe</h2>
#
# <h3>Requirements</h3>
# <ul>
#     <li>Name of the Dataframes</li>
#     <li>Filepath</li>
# </ul>

# %%
penguins = pd.read_csv('datasets\\penguins.csv')

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen            39.1           18.7
# 1        2     Adelie  Torgersen            39.5           17.4
# 2        3     Adelie  Torgersen            40.3           18.0
# 3        4     Adelie  Torgersen             NaN            NaN
# 4        5     Adelie  Torgersen            36.7           19.3
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream            55.8           19.8
# 340    341  Chinstrap      Dream            43.5           18.1
# 341    342  Chinstrap      Dream            49.6           18.2
# 342    343  Chinstrap      Dream            50.8           19.0
# 343    344  Chinstrap      Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# ...

# %% [markdown]
# <h2>Descriptive Analysis</h2>

# %%
penguins.describe()
# Out:
#             rowid  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# count  344.000000      342.000000     342.000000         342.000000
# mean   172.500000       43.921930      17.151170         200.915205
# std     99.448479        5.459584       1.974793          14.061714
# min      1.000000       32.100000      13.100000         172.000000
# 25%     86.750000       39.225000      15.600000         190.000000
# 50%    172.500000       44.450000      17.300000         197.000000
# 75%    258.250000       48.500000      18.700000         213.000000
# max    344.000000       59.600000      21.500000         231.000000
#
#        body_mass_g         year
# count   342.000000   344.000000
# mean   4201.754386  2008.029070
# std     801.954536     0.818356
# min    2700.000000  2007.000000
# 25%    3550.000000  2007.000000
# 50%    4050.000000  2008.000000
# 75%    4750.000000  2009.000000
# max    6300.000000  2009.000000

# %%
penguins.describe().T
# Out:
#                    count         mean         std     min       25%      50%  \
# rowid              344.0   172.500000   99.448479     1.0    86.750   172.50
# bill_length_mm     342.0    43.921930    5.459584    32.1    39.225    44.45
# bill_depth_mm      342.0    17.151170    1.974793    13.1    15.600    17.30
# flipper_length_mm  342.0   200.915205   14.061714   172.0   190.000   197.00
# body_mass_g        342.0  4201.754386  801.954536  2700.0  3550.000  4050.00
# year               344.0  2008.029070    0.818356  2007.0  2007.000  2008.00
#
#                        75%     max
# rowid               258.25   344.0
# bill_length_mm       48.50    59.6
# bill_depth_mm        18.70    21.5
# flipper_length_mm   213.00   231.0
# body_mass_g        4750.00  6300.0
# year               2009.00  2009.0

# %% [markdown]
# <h2>Checking Null Values</h2>

# %%
penguins.isnull()
# Out:
#      rowid  species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    False    False   False           False          False              False
# 1    False    False   False           False          False              False
# 2    False    False   False           False          False              False
# 3    False    False   False            True           True               True
# 4    False    False   False           False          False              False
# ..     ...      ...     ...             ...            ...                ...
# 339  False    False   False           False          False              False
# 340  False    False   False           False          False              False
# 341  False    False   False           False          False              False
# 342  False    False   False           False          False              False
# 343  False    False   False           False          False              False
#
#      body_mass_g    sex   year
# ...

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %% [markdown]
# <h2>Filtering a column</h2>

# %%
penguins['species']
# Out:
# 0         Adelie
# 1         Adelie
# 2         Adelie
# 3         Adelie
# 4         Adelie
#          ...
# 339    Chinstrap
# 340    Chinstrap
# 341    Chinstrap
# 342    Chinstrap
# 343    Chinstrap
# Name: species, Length: 344, dtype: object

# %%
penguins['species'].value_counts()
# Out:
# species
# Adelie       152
# Gentoo       124
# Chinstrap     68
# Name: count, dtype: int64

# %%
penguins[penguins['species'] == 'Adelie']
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 0        1  Adelie  Torgersen            39.1           18.7
# 1        2  Adelie  Torgersen            39.5           17.4
# 2        3  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen             NaN            NaN
# 4        5  Adelie  Torgersen            36.7           19.3
# ..     ...     ...        ...             ...            ...
# 147    148  Adelie      Dream            36.6           18.4
# 148    149  Adelie      Dream            36.0           17.8
# 149    150  Adelie      Dream            37.8           18.1
# 150    151  Adelie      Dream            36.0           17.1
# 151    152  Adelie      Dream            41.5           18.5
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %%
penguins[penguins['species'] != 'Adelie']
# Out:
#      rowid    species  island  bill_length_mm  bill_depth_mm  \
# 152    153     Gentoo  Biscoe            46.1           13.2
# 153    154     Gentoo  Biscoe            50.0           16.3
# 154    155     Gentoo  Biscoe            48.7           14.1
# 155    156     Gentoo  Biscoe            50.0           15.2
# 156    157     Gentoo  Biscoe            47.6           14.5
# ..     ...        ...     ...             ...            ...
# 339    340  Chinstrap   Dream            55.8           19.8
# 340    341  Chinstrap   Dream            43.5           18.1
# 341    342  Chinstrap   Dream            49.6           18.2
# 342    343  Chinstrap   Dream            50.8           19.0
# 343    344  Chinstrap   Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 152              211.0       4500.0  female  2007
# 153              230.0       5700.0    male  2007
# 154              210.0       4450.0  female  2007
# ...

# %%
Adelie_df = penguins[penguins['species'] == 'Adelie']

# %%
Adelie_df
# Out:
#      rowid species     island  bill_length_mm  bill_depth_mm  \
# 0        1  Adelie  Torgersen            39.1           18.7
# 1        2  Adelie  Torgersen            39.5           17.4
# 2        3  Adelie  Torgersen            40.3           18.0
# 3        4  Adelie  Torgersen             NaN            NaN
# 4        5  Adelie  Torgersen            36.7           19.3
# ..     ...     ...        ...             ...            ...
# 147    148  Adelie      Dream            36.6           18.4
# 148    149  Adelie      Dream            36.0           17.8
# 149    150  Adelie      Dream            37.8           18.1
# 150    151  Adelie      Dream            36.0           17.1
# 151    152  Adelie      Dream            41.5           18.5
#
#      flipper_length_mm  body_mass_g     sex  year
# 0                181.0       3750.0    male  2007
# 1                186.0       3800.0  female  2007
# 2                195.0       3250.0  female  2007
# ...

# %%
Gentoo_df = penguins[penguins['species'] == 'Gentoo']

# %%
Gentoo_df
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 152    153  Gentoo  Biscoe            46.1           13.2              211.0
# 153    154  Gentoo  Biscoe            50.0           16.3              230.0
# 154    155  Gentoo  Biscoe            48.7           14.1              210.0
# 155    156  Gentoo  Biscoe            50.0           15.2              218.0
# 156    157  Gentoo  Biscoe            47.6           14.5              215.0
# ..     ...     ...     ...             ...            ...                ...
# 271    272  Gentoo  Biscoe             NaN            NaN                NaN
# 272    273  Gentoo  Biscoe            46.8           14.3              215.0
# 273    274  Gentoo  Biscoe            50.4           15.7              222.0
# 274    275  Gentoo  Biscoe            45.2           14.8              212.0
# 275    276  Gentoo  Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex  year
# ...

# %%
Chinstrap_df = penguins[penguins['species'] == 'Chinstrap']

# %%
Chinstrap_df
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 276    277  Chinstrap  Dream            46.5           17.9
# 277    278  Chinstrap  Dream            50.0           19.5
# 278    279  Chinstrap  Dream            51.3           19.2
# 279    280  Chinstrap  Dream            45.4           18.7
# 280    281  Chinstrap  Dream            52.7           19.8
# ..     ...        ...    ...             ...            ...
# 339    340  Chinstrap  Dream            55.8           19.8
# 340    341  Chinstrap  Dream            43.5           18.1
# 341    342  Chinstrap  Dream            49.6           18.2
# 342    343  Chinstrap  Dream            50.8           19.0
# 343    344  Chinstrap  Dream            50.2           18.7
#
#      flipper_length_mm  body_mass_g     sex  year
# 276              192.0       3500.0  female  2007
# 277              196.0       3900.0    male  2007
# 278              193.0       3650.0    male  2007
# ...

# %%
penguins[penguins['body_mass_g'] >= 4000]
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 7        8     Adelie  Torgersen            39.2           19.6
# 9       10     Adelie  Torgersen            42.0           20.2
# 14      15     Adelie  Torgersen            34.6           21.1
# 17      18     Adelie  Torgersen            42.5           20.7
# 19      20     Adelie  Torgersen            46.0           21.5
# ..     ...        ...        ...             ...            ...
# 323    324  Chinstrap      Dream            49.0           19.6
# 329    330  Chinstrap      Dream            50.7           19.7
# 333    334  Chinstrap      Dream            49.3           19.9
# 339    340  Chinstrap      Dream            55.8           19.8
# 342    343  Chinstrap      Dream            50.8           19.0
#
#      flipper_length_mm  body_mass_g   sex  year
# 7                195.0       4675.0  male  2007
# 9                190.0       4250.0   NaN  2007
# 14               198.0       4400.0  male  2007
# ...

# %%
penguins[(penguins['species']== 'Chinstrap') & (penguins['body_mass_g'] >= 4000)]
# Out:
#      rowid    species island  bill_length_mm  bill_depth_mm  \
# 284    285  Chinstrap  Dream            46.0           18.9
# 289    290  Chinstrap  Dream            52.0           18.1
# 291    292  Chinstrap  Dream            50.5           19.6
# 295    296  Chinstrap  Dream            49.2           18.2
# 301    302  Chinstrap  Dream            52.0           19.0
# 305    306  Chinstrap  Dream            52.8           20.0
# 307    308  Chinstrap  Dream            54.2           20.8
# 309    310  Chinstrap  Dream            51.0           18.8
# 313    314  Chinstrap  Dream            52.0           20.7
# 315    316  Chinstrap  Dream            53.5           19.9
# 321    322  Chinstrap  Dream            50.8           18.5
# 323    324  Chinstrap  Dream            49.0           19.6
# 329    330  Chinstrap  Dream            50.7           19.7
# 333    334  Chinstrap  Dream            49.3           19.9
# 339    340  Chinstrap  Dream            55.8           19.8
# ...

# %% [markdown]
# <h2>FILLING UP NULL VALUES</h2>

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    object
#  2   island             344 non-null    object
#  3   bill_length_mm     342 non-null    float64
#  4   bill_depth_mm      342 non-null    float64
#  5   flipper_length_mm  342 non-null    float64
#  6   body_mass_g        342 non-null    float64
#  7   sex                333 non-null    object
#  8   year               344 non-null    int64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 24.3+ KB

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         2
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_depth_mm'] = penguins['bill_depth_mm'].fillna(penguins['bill_depth_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        2
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['bill_length_mm'] = penguins['bill_length_mm'].fillna(penguins['bill_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     2
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['flipper_length_mm'] = penguins['flipper_length_mm'].fillna(penguins['flipper_length_mm'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           2
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['body_mass_g'] = penguins['body_mass_g'].fillna(penguins['body_mass_g'].mean())

# %%
penguins.isnull().sum()
# Out:
# rowid                 0
# species               0
# island                0
# bill_length_mm        0
# bill_depth_mm         0
# flipper_length_mm     0
# body_mass_g           0
# sex                  11
# year                  0
# dtype: int64

# %%
penguins['sex'].mode()
# Out:
# 0    male
# Name: sex, dtype: object

# %%
penguins['sex'] = penguins['sex'].fillna(penguins['sex'].mode()[0])

# %%
penguins.isnull().sum()
# Out:
# rowid                0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %% [markdown]
# <h2>Changing the Data Type</h2>

# %%
penguins['species'] = penguins['species'].astype('category')
penguins['year'] = penguins['year'].astype('category')
penguins['sex'] = penguins['sex'].astype('category')
penguins['island'] = penguins['island'].astype('category')

# %%
penguins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              344 non-null    int64
#  1   species            344 non-null    category
#  2   island             344 non-null    category
#  3   bill_length_mm     344 non-null    float64
#  4   bill_depth_mm      344 non-null    float64
#  5   flipper_length_mm  344 non-null    float64
#  6   body_mass_g        344 non-null    float64
#  7   sex                344 non-null    category
#  8   year               344 non-null    category
# dtypes: category(4), float64(4), int64(1)
# memory usage: 15.4 KB

# %%
penguins['mass_kg'] = np.round(penguins['body_mass_g'] / 1000 , 1)

# %%
penguins
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 0        1     Adelie  Torgersen        39.10000       18.70000
# 1        2     Adelie  Torgersen        39.50000       17.40000
# 2        3     Adelie  Torgersen        40.30000       18.00000
# 3        4     Adelie  Torgersen        43.92193       17.15117
# 4        5     Adelie  Torgersen        36.70000       19.30000
# ..     ...        ...        ...             ...            ...
# 339    340  Chinstrap      Dream        55.80000       19.80000
# 340    341  Chinstrap      Dream        43.50000       18.10000
# 341    342  Chinstrap      Dream        49.60000       18.20000
# 342    343  Chinstrap      Dream        50.80000       19.00000
# 343    344  Chinstrap      Dream        50.20000       18.70000
#
#      flipper_length_mm  body_mass_g     sex  year  mass_kg
# 0           181.000000  3750.000000    male  2007      3.8
# 1           186.000000  3800.000000  female  2007      3.8
# ...

# %%
penguins.columns
# Out:
# Index(['rowid', 'species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'year', 'mass_kg'],
#       dtype='object')

# %%
penguins['mass_kg'].min()
# Out:
# np.float64(2.7)

# %%
penguins['mass_kg'].max()
# Out:
# np.float64(6.3)

# %%
penguins[penguins['mass_kg'] == 6.3]
# Out:
#      rowid species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 169    170  Gentoo  Biscoe            49.2           15.2              221.0
#
#      body_mass_g   sex  year  mass_kg
# 169       6300.0  male  2007      6.3

# %%
penguins['mass_kg'].mean()
# Out:
# np.float64(4.2020348837209305)

# %%
penguins[penguins['mass_kg'] == 4]
# Out:
#      rowid    species     island  bill_length_mm  bill_depth_mm  \
# 23      24     Adelie     Biscoe            38.2           18.1
# 29      30     Adelie     Biscoe            40.5           18.9
# 36      37     Adelie      Dream            38.8           20.0
# 53      54     Adelie     Biscoe            42.0           19.5
# 63      64     Adelie     Biscoe            41.1           18.2
# 65      66     Adelie     Biscoe            41.6           18.0
# 79      80     Adelie  Torgersen            42.1           19.1
# 88      89     Adelie      Dream            38.3           19.2
# 125    126     Adelie  Torgersen            40.6           19.0
# 129    130     Adelie  Torgersen            44.1           18.0
# 137    138     Adelie      Dream            40.2           20.1
# 151    152     Adelie      Dream            41.5           18.5
# 192    193     Gentoo     Biscoe            42.7           13.7
# 281    282  Chinstrap      Dream            45.2           17.8
# ...

# %% [markdown]
# <h1>Exploratory Data Analytics</h1>
# <hr>

# %% [markdown]
# <h2>Question 1</h2>
# <h3>What is the average body mass in kg of all penguins?</h3>

# %%
np.round(penguins['mass_kg'].mean())
# Out:
# np.float64(4.0)

# %% [markdown]
# <h2>Insight:</h2>
# <p>Base on the Dataset the average body mass in kg of all penguins is 4.0 kg.</p>

# %% [markdown]
# <h2>Question 2</h2>
# <h3>How many male and female penguins are in the Biscoe island?</h3>

# %%
penguins[penguins['island'] == 'Biscoe']['sex'].value_counts()
# Out:
# sex
# male      88
# female    80
# Name: count, dtype: int64

# %% [markdown]
# <h2>Insight:</h2>
# <p>There are 88 male and 80 female in the Biscoe island.</p>

# %% [markdown]
# <h2>Question 3</h2>
# <h3>Which island has the highest number of penguins?</h3>

# %%
penguins['island'].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %% [markdown]
# <h2>Insight:</h2>
# <p>Biscoe island has the hightest number of penguins.</p>

# %% [markdown]
# <h2>Question 4</h2>
# <h3>What is the average flipper length by species?</h3>

# %%
np.round(penguins.groupby('species')['flipper_length_mm'].mean())
# Out:
# C:\Users\This PC\AppData\Local\Temp\ipykernel_12868\606653159.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   np.round(penguins.groupby('species')['flipper_length_mm'].mean())
# species
# Adelie       190.0
# Chinstrap    196.0
# Gentoo       217.0
# Name: flipper_length_mm, dtype: float64

# %% [markdown]
# <h2>Insight:</h2>
# <p>Based on the result, the average flipper length of the Gentoo species is 217.0mm.</p>

# %% [markdown]
# <h3>Question 5</h3>
# <h3> What is the smallest mass_kg recorded?</h3>

# %%
penguins['mass_kg'].min()
# Out:
# np.float64(2.7)

# %% [markdown]
# <h2>Insight:</h2>
# <p>The smallest mass_kg recorded is 2.7kg.</p>

# %% [markdown]
# <h2>Question 6</h2>
# <h3> What is the average bill length of Adelie for each year?</h3>

# %%
np.round(penguins[penguins['species'] == 'Adelie'].groupby('year')['bill_length_mm'].mean())
# Out:
# C:\Users\This PC\AppData\Local\Temp\ipykernel_12868\1260497108.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   np.round(penguins[penguins['species'] == 'Adelie'].groupby('year')['bill_length_mm'].mean())
# year
# 2007    39.0
# 2008    39.0
# 2009    39.0
# Name: bill_length_mm, dtype: float64

# %% [markdown]
# <h2>Insight:</h2>
# <p>Based on the result, there are no changes in bill length for each year.</p>

# %% [markdown]
# <h2>Question 7</h2>
# <h3>What is the average bill depth for male and female penguins?</h3>

# %%
np.round(penguins.groupby('sex')['bill_depth_mm'].mean())
# Out:
# C:\Users\This PC\AppData\Local\Temp\ipykernel_12868\3432808965.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   np.round(penguins.groupby('sex')['bill_depth_mm'].mean())
# sex
# female    16.0
# male      18.0
# Name: bill_depth_mm, dtype: float64

# %% [markdown]
# <h2>Insight:</h2>
# <p>Based on the result, the average bill depth of males is 18.0 mm, while females have an average of 16.0 mm.</p>
